// %% [markdown]
// # Interactive Kotlin Econometrics Exploration
//
// Welcome to the Kotlin Jupyter notebook! You can use this to explore data using Kotlin.

// %%
%use lets-plot
%use dataframe

import org.jetbrains.kotlinx.dataframe.api.*
import org.jetbrains.kotlinx.dataframe.io.*

// %% [markdown]
// ## 1. Load Macroeconomic Data (FRED)

// %%
val dfFred = DataFrame.readCSV("fred_macro.csv")
dfFred.head()
